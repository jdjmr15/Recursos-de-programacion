# %% [markdown]
# # Calculadora con ciclo repetitivo en Python
#
# Calculadora con ciclo repetitivos, la importanción de modulo y la inclusión del cálculo del factorial de un número en Python

# %%
import os
from modulo.operaciones import sumar, restar, multiplicar, dividir

# Constantes
OPERADORES_VALIDOS = ["+", "-", "*", "/", "!"]
